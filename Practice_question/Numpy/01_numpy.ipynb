# %% [markdown]
# # 🔰 1️⃣ Basic Practice (Foundation Strong Karo)
# ## ✅ Daily 30 min Practice Plan
# ### 🔹 (1) Array Banana Seekho
# 1. np.array()
# 2. np.zeros()
# 3. np.ones()
# 4. np.arange()
# 5. np.linspace()
# 5. np.random.randint()

# %% [markdown]
# ### 🔹 (2) Shape & Size Samjh
# 1. .shape
# 2. .size
# 3. .ndim
# 4. .reshape()

# %% [markdown]
# # 🔰 2️⃣ Calculation Practice (Most Important 🔥)
# ### 🔹 Basic Operations
# #### 1️⃣ Addition
# 1. `+` `→ np.add()`
#
# #### 2️⃣ Subtraction
# - `→` `np.subtract()`
#
# #### 3️⃣ Multiplication
# `*` `→ np.multiply()`
#
# #### 4️⃣ Division
# `/` `→ np.divide()`

# %% [markdown]
# # 🔹 Important Functions
# 1. np.sum()
# 2. np.mean()
# 3. np.min()
# 4. np.max()
# 5. np.std()
# 6. np.var()

# %% [markdown]
# # 🔰 3️⃣ Matrix Practice (Very Important)
# 1. 🔹 Matrix Addition
# 2. 🔹 Matrix Multiplication
# 3. 🔹 Dot Product
# 4. 🔹 Transpose
# 5. 🔹 Determinant
# 6. 🔹 Inverse

# %% [markdown]
# # 🔰 4️⃣ Advanced Level
# 1. Boolean Indexing
# 2. Slicing
# 3. Broadcasting
# 4. Stacking (`vstack, hstack`)
# 4. Concatenate
