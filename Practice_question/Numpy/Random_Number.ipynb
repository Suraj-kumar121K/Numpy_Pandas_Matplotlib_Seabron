# %% [markdown]
# 🔹 1️⃣ Basic Random (0 to 1)
#
# Create a 1D random array of 5 elements between 0 and 1.
#
# Create a 3x3 random array between 0 and 1.
#
# Set random seed to 10 and generate a 2x2 random array.
#
# Generate a 4x4 random array and round values to 2 decimal places.

# %% [markdown]
# 🔹 2️⃣ Random Integers
#
# Create a random integer array from 1 to 10 of size 5.
#
# Create a 3x3 random integer matrix from 10 to 50.
#
# Generate 6 random integers between -5 and 5.
#
# Create a 2x4 matrix with random integers from 100 to 200.

# %% [markdown]
# 🔹 3️⃣ Random Choice
#
# Randomly select 5 elements from [10, 20, 30, 40, 50].
#
# Randomly select 3 elements without replacement from `[1,2,3,4,5]`.
#
# Generate a 2x3 array by randomly choosing from `[0,1]`.
#
# Generate 10 random values from `['A','B','C']`.

# %% [markdown]
# 🔹 5️⃣ Mixed Practice
#
# Generate a 1D random array of 10 numbers and find the maximum value.
#
# Generate a 3x3 random integer matrix and find the minimum value.
#
# Generate a random array of 20 numbers and sort them.
#
# Create two 2x2 random arrays and add them.
#
# Generate a 4x4 random array and reshape it into 2x8.
