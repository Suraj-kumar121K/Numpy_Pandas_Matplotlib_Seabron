# %% [markdown]
# # 📘 What is pandas
# Pandas is a python labrary used to data analysis and data manipulation.

# %% [markdown]
# # What is Series
# A Series is a one-dimensional labeled array that can store any type of data — integers, floats, strings, or Python objects.
#
# # 🔹 Syntax
# `pd.Series(data)`

# %% [markdown]
# # Import pandas

# %%
import pandas as pd

# %% [markdown]
# # 📘 Pandas Series Question
# 1. List se ek Series create karo: `[10, 20, 30, 40]`

# %%
df = pd.Series([10, 20, 30, 40,])
df
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# 2. Custom index ke sath Series banao:
# - Data: `[100, 200, 300]`
# - Index: `['a', 'b', 'c']`

# %%
df = pd.Series([100, 200, 300], index=['a', 'b', 'c'])
df
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %% [markdown]
# 3. Dictionary se Series create karo:
# - `{'Math': 90, 'English': 85, 'Science': 88}`

# %%
data = {'Math':90, 'English':'85', 'Scinece':88}
df = pd.Series(data)
df
# Out:
# Math       90
# English    85
# Scinece    88
# dtype: object

# %% [markdown]
# 4. Single value se 5 elements ki Series banao `(value = 50)`

# %% [markdown]
# 5. NumPy array se Series create karo.

# %% [markdown]
# 6. Series me custom index assign karo baad me.

# %% [markdown]
# 7. String data se Series banao: ["Apple", "Banana", "Mango"]

# %% [markdown]
# 8. Boolean values ki Series create karo.

# %% [markdown]
# 9. Float values ki Series banao.

# %% [markdown]
# 10. Date range use karke Series create karo.

# %% [markdown]
# # 📊 What is DataFrame
# A DataFrame is a two-dimensional labeled data structure in Pandas, like a table with rows and columns

# %% [markdown]
# # 🔹 Pandas DataFrame Question
#
# 1. Dictionary se DataFrame create karo:
# - `Name:` `-` `Aman, Suraj, Ravi`
# - `Marks:` `-` `80, 90, 75`
#
# 2. List of lists se DataFrame banao.
#
# 3. List of dictionaries se DataFrame create karo.
#
# 4. NumPy array se DataFrame create karo.
#
# 5. Custom row index ke sath DataFrame banao.
#
# 6. 3 columns aur 5 rows ka random DataFrame create karo.
#
# 7. Empty DataFrame create karo.
#
# 8. CSV file read karke DataFrame banao.
#
# 9. Excel file read karke DataFrame create karo.
#
# 10. Dictionary of Series se DataFrame create karo.
